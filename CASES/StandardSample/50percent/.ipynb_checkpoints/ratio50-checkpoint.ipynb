# %% [markdown]
# ## 1: background intensity

# %%
from PyXplore import WPEM
import pandas as pd
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2026-02-06 15:21:18  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,LFctg=0.2, lowAngleRange=20, window_length = 7, bac_num=500)
# Out:
# ================================

# %% [markdown]
# ## 2: Wpen fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [[ 5.63417,  5.63417,  5.63417, 90.     , 90.     , 90., ],
                     [  8.36041,   4.97669,   6.19737,  90   , 114.6978 ,  90 , 'fixed' ]]

# Execute the model
WPEM.XRDfit(
    wavelength, var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=11 ,low_bound=20,up_bound=50,bta = 0.9,iter_max = 100, asy_C = 0, 
    InitializationEpoch=2, num=7,Ave_Waves=True,)
# Out:
# Started at Fri Feb  6 15:21:56 2026
#
# The lattice constants of input system 1 are fixed
# viz., fixed : [8.36041, 4.97669, 6.19737, 90, 114.6978, 90]
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Cubic  |  The initial lattice constants : 5.63417 5.63417 5.63417 90.0 90.0 90.0
# The input crystal system is: Monoclinic  |  The initial lattice constants : 8.36041 4.97669 6.19737 90 114.6978 90
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                   | 0/100 [00:00<?, ?it/s]WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 1-th iteration
# [array([ 5.63417,  5.63417,  5.63417, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   1%|▍                                          | 1/100 [00:12<20:51, 12.64s/it]
# Rp:31.265 | Rwp:50.395 | Rsquare:8.437
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 2-th iteration
# [array([ 5.63417,  5.63417,  5.63417, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   2%|▊                                          | 2/100 [00:24<19:38, 12.02s/it]
# Rp:24.061 | Rwp:36.826 | Rsquare:5.538
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 3-th iteration
# [array([ 5.63495,  5.63495,  5.63495, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   3%|█▎                                         | 3/100 [00:35<19:00, 11.75s/it]
# Rp:22.785 | Rwp:33.625 | Rsquare:5.267
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 4-th iteration
# [array([ 5.63513,  5.63513,  5.63513, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   4%|█▋                                         | 4/100 [00:46<18:27, 11.53s/it]
# Rp:21.977 | Rwp:31.954 | Rsquare:5.144
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 5-th iteration
# [array([ 5.63521,  5.63521,  5.63521, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   5%|██▏                                        | 5/100 [00:58<18:09, 11.47s/it]
# Rp:21.420 | Rwp:30.977 | Rsquare:4.918
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 6-th iteration
# [array([ 5.63523,  5.63523,  5.63523, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   6%|██▌                                        | 6/100 [01:09<17:49, 11.38s/it]
# Rp:20.946 | Rwp:30.272 | Rsquare:4.638
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 7-th iteration
# [array([ 5.63523,  5.63523,  5.63523, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   7%|███                                        | 7/100 [01:20<17:39, 11.39s/it]
# Rp:20.521 | Rwp:29.689 | Rsquare:4.342
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 8-th iteration
# [array([ 5.63523,  5.63523,  5.63523, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   8%|███▍                                       | 8/100 [01:32<17:25, 11.37s/it]
# Rp:20.156 | Rwp:29.159 | Rsquare:4.052
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 9-th iteration
# [array([ 5.63522,  5.63522,  5.63522, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   9%|███▊                                       | 9/100 [01:43<17:13, 11.35s/it]
# Rp:19.805 | Rwp:28.649 | Rsquare:3.783
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 10-th iteration
# [array([ 5.63521,  5.63521,  5.63521, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  10%|████▏                                     | 10/100 [01:54<16:50, 11.23s/it]
# Rp:19.466 | Rwp:28.147 | Rsquare:3.543
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 11-th iteration
# [array([ 5.63521,  5.63521,  5.63521, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  11%|████▌                                     | 11/100 [02:05<16:34, 11.17s/it]
# Rp:19.128 | Rwp:27.650 | Rsquare:3.334
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 12-th iteration
# [array([ 5.6352,  5.6352,  5.6352, 90.    , 90.    , 90.    ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  12%|█████                                     | 12/100 [02:16<16:21, 11.16s/it]
# Rp:18.796 | Rwp:27.152 | Rsquare:3.157
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 13-th iteration
# [array([ 5.6352,  5.6352,  5.6352, 90.    , 90.    , 90.    ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  13%|█████▍                                    | 13/100 [02:27<16:09, 11.14s/it]
# Rp:18.481 | Rwp:26.641 | Rsquare:3.006
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 14-th iteration
# [array([ 5.63521,  5.63521,  5.63521, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  14%|█████▉                                    | 14/100 [02:38<15:54, 11.10s/it]
# Rp:18.173 | Rwp:26.106 | Rsquare:2.880
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 15-th iteration
# [array([ 5.63522,  5.63522,  5.63522, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  15%|██████▎                                   | 15/100 [02:49<15:39, 11.06s/it]
# Rp:17.876 | Rwp:25.587 | Rsquare:2.772
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 16-th iteration
# [array([ 5.63523,  5.63523,  5.63523, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  16%|██████▋                                   | 16/100 [03:00<15:25, 11.02s/it]
# Rp:17.596 | Rwp:25.134 | Rsquare:2.671
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 17-th iteration
# [array([ 5.63526,  5.63526,  5.63526, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  17%|███████▏                                  | 17/100 [03:11<15:15, 11.03s/it]
# Rp:17.342 | Rwp:24.743 | Rsquare:2.569
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 18-th iteration
# [array([ 5.63528,  5.63528,  5.63528, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  18%|███████▌                                  | 18/100 [03:22<15:04, 11.03s/it]
# Rp:17.107 | Rwp:24.399 | Rsquare:2.468
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 19-th iteration
# [array([ 5.6353,  5.6353,  5.6353, 90.    , 90.    , 90.    ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  19%|███████▉                                  | 19/100 [03:33<14:58, 11.09s/it]
# Rp:16.900 | Rwp:24.093 | Rsquare:2.369
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 20-th iteration
# [array([ 5.63532,  5.63532,  5.63532, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  20%|████████▍                                 | 20/100 [03:44<14:46, 11.08s/it]
# Rp:16.705 | Rwp:23.821 | Rsquare:2.276
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 21-th iteration
# [array([ 5.63533,  5.63533,  5.63533, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  21%|████████▊                                 | 21/100 [03:56<14:48, 11.25s/it]
# Rp:16.518 | Rwp:23.580 | Rsquare:2.189
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 22-th iteration
# [array([ 5.63535,  5.63535,  5.63535, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  22%|█████████▏                                | 22/100 [04:07<14:34, 11.21s/it]
# Rp:16.343 | Rwp:23.367 | Rsquare:2.110
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 23-th iteration
# [array([ 5.63536,  5.63536,  5.63536, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  23%|█████████▋                                | 23/100 [04:19<14:25, 11.24s/it]
# Rp:16.192 | Rwp:23.179 | Rsquare:2.037
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 24-th iteration
# [array([ 5.63537,  5.63537,  5.63537, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  24%|██████████                                | 24/100 [04:30<14:14, 11.25s/it]
# Rp:16.052 | Rwp:23.014 | Rsquare:1.970
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 25-th iteration
# [array([ 5.63538,  5.63538,  5.63538, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  25%|██████████▌                               | 25/100 [04:41<14:01, 11.22s/it]
# Rp:15.920 | Rwp:22.869 | Rsquare:1.910
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 26-th iteration
# [array([ 5.63538,  5.63538,  5.63538, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  26%|██████████▉                               | 26/100 [04:52<13:47, 11.18s/it]
# Rp:15.795 | Rwp:22.742 | Rsquare:1.855
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 27-th iteration
# [array([ 5.63539,  5.63539,  5.63539, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  27%|███████████▎                              | 27/100 [05:03<13:38, 11.21s/it]
# Rp:15.676 | Rwp:22.630 | Rsquare:1.805
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 28-th iteration
# [array([ 5.63539,  5.63539,  5.63539, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  28%|███████████▊                              | 28/100 [05:15<13:47, 11.49s/it]
# Rp:15.570 | Rwp:22.532 | Rsquare:1.759
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 29-th iteration
# [array([ 5.6354,  5.6354,  5.6354, 90.    , 90.    , 90.    ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  29%|████████████▏                             | 29/100 [05:27<13:41, 11.58s/it]
# Rp:15.471 | Rwp:22.446 | Rsquare:1.718
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 30-th iteration
# [array([ 5.6354,  5.6354,  5.6354, 90.    , 90.    , 90.    ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  30%|████████████▌                             | 30/100 [05:39<13:35, 11.65s/it]
# Rp:15.386 | Rwp:22.371 | Rsquare:1.681
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 31-th iteration
# [array([ 5.6354,  5.6354,  5.6354, 90.    , 90.    , 90.    ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  31%|█████████████                             | 31/100 [05:51<13:22, 11.63s/it]
# Rp:15.318 | Rwp:22.305 | Rsquare:1.647
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 32-th iteration
# [array([ 5.6354,  5.6354,  5.6354, 90.    , 90.    , 90.    ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  32%|█████████████▍                            | 32/100 [06:02<13:08, 11.59s/it]
# Rp:15.255 | Rwp:22.247 | Rsquare:1.616
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 33-th iteration
# [array([ 5.6354,  5.6354,  5.6354, 90.    , 90.    , 90.    ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  33%|█████████████▊                            | 33/100 [06:14<12:53, 11.54s/it]
# Rp:15.195 | Rwp:22.196 | Rsquare:1.588
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 34-th iteration
# [array([ 5.6354,  5.6354,  5.6354, 90.    , 90.    , 90.    ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  34%|██████████████▎                           | 34/100 [06:25<12:40, 11.53s/it]
# Rp:15.139 | Rwp:22.151 | Rsquare:1.562
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 35-th iteration
# [array([ 5.6354,  5.6354,  5.6354, 90.    , 90.    , 90.    ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  35%|██████████████▋                           | 35/100 [06:36<12:27, 11.49s/it]
# Rp:15.086 | Rwp:22.112 | Rsquare:1.539
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 36-th iteration
# [array([ 5.63539,  5.63539,  5.63539, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  35%|██████████████▋                           | 35/100 [06:48<12:39, 11.68s/it]
# Rp:15.037 | Rwp:22.078 | Rsquare:1.517
# After update the background :   Rp = 12.104 | Rwp = 20.343 | Rsquare = 1.476
# Mass fraction without structure factor estimate in % : [47.54037252277412, 52.459627477225865]
#  Saved at the result documents
# 36-th iterations, reach the limit of ϵ.
#  Rp: 12.104
# Rwp: 20.343
#
#
# WPEM program running time :  0 hours 6 minute  55 second
# ('0 hours 6 minute  55 second  ',
#  [array([ 5.63539,  5.63539,  5.63539, 90.     , 90.     , 90.     ]),
#   array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])])
