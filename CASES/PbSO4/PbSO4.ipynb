# %% [markdown]
# # PbSO4

# %% [markdown]
# ## 1: background intensity

# %%
from PyXplore import WPEM
import pandas as pd
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2026-02-05 15:39:50  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,bac_num=1000)
# Out:
# ================================

# %% [markdown]
# ## 2: Wpen fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.
Lattice_constants = [[8.48527, 5.40156, 6.9642, 90, 90, 90],]

# Execute the model
WPEM.XRDfit(
    wavelength, var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=9,low_bound=20,up_bound=50,bta = 0.85,iter_max = 700, asy_C = 0
    )
# Out:
# Started at Thu Feb  5 15:41:50 2026
#
# Initialization
# --------------------------------------------------------------------------------
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 8.48527 5.40156 6.9642 90 90 90
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                   | 0/700 [00:00<?, ?it/s]WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 1-th iteration
# [array([ 8.48527,  5.40156,  6.9642 , 90.     , 90.     , 90.     ])]
#   0%|                                         | 1/700 [00:44<8:37:14, 44.40s/it]
# Rp:22.211 | Rwp:31.948 | Rsquare:9.888
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 2-th iteration
# [array([ 8.48527,  5.40156,  6.9642 , 90.     , 90.     , 90.     ])]
#   0%|                                         | 2/700 [01:29<8:38:00, 44.53s/it]
# Rp:14.001 | Rwp:20.300 | Rsquare:3.087
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 3-th iteration
# [array([ 8.48558,  5.40237,  6.96448, 90.     , 90.     , 90.     ])]
#   0%|▏                                        | 3/700 [02:28<9:58:04, 51.48s/it]
# Rp:14.015 | Rwp:19.610 | Rsquare:3.816
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 4-th iteration
# [array([ 8.48566,  5.40258,  6.96442, 90.     , 90.     , 90.     ])]
#   1%|▏                                       | 4/700 [03:29<10:40:49, 55.24s/it]
# Rp:12.470 | Rwp:17.343 | Rsquare:3.069
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 5-th iteration
# [array([ 8.48571,  5.40272,  6.96436, 90.     , 90.     , 90.     ])]
#   1%|▎                                       | 5/700 [04:28<10:52:57, 56.37s/it]
# Rp:11.469 | Rwp:15.910 | Rsquare:2.581
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 6-th iteration
# [array([ 8.48572,  5.40283,  6.96431, 90.     , 90.     , 90.     ])]
#   1%|▎                                       | 6/700 [05:21<10:40:07, 55.34s/it]
# Rp:10.733 | Rwp:14.872 | Rsquare:2.217
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 7-th iteration
# [array([ 8.48572,  5.40291,  6.96427, 90.     , 90.     , 90.     ])]
#   1%|▍                                       | 7/700 [06:18<10:46:08, 55.94s/it]
# Rp:10.162 | Rwp:14.062 | Rsquare:1.933
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 8-th iteration
# [array([ 8.48572,  5.40298,  6.96423, 90.     , 90.     , 90.     ])]
#   1%|▍                                       | 8/700 [07:13<10:39:16, 55.43s/it]
# Rp:9.699 | Rwp:13.401 | Rsquare:1.709
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 9-th iteration
# [array([ 8.48571,  5.40302,  6.9642 , 90.     , 90.     , 90.     ])]
#   1%|▌                                       | 9/700 [08:06<10:32:45, 54.94s/it]
# Rp:9.315 | Rwp:12.849 | Rsquare:1.530
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 10-th iteration
# [array([ 8.4857 ,  5.40306,  6.96418, 90.     , 90.     , 90.     ])]
#   1%|▌                                      | 10/700 [09:01<10:32:02, 54.96s/it]
# Rp:8.986 | Rwp:12.382 | Rsquare:1.385
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 11-th iteration
# [array([ 8.48569,  5.40309,  6.96416, 90.     , 90.     , 90.     ])]
#   2%|▌                                      | 11/700 [09:54<10:23:29, 54.30s/it]
# Rp:8.701 | Rwp:11.984 | Rsquare:1.268
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 12-th iteration
# [array([ 8.48568,  5.4031 ,  6.96415, 90.     , 90.     , 90.     ])]
#   2%|▋                                      | 12/700 [10:45<10:12:06, 53.38s/it]
# Rp:8.450 | Rwp:11.641 | Rsquare:1.170
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 13-th iteration
# [array([ 8.4857 ,  5.40315,  6.96409, 90.     , 90.     , 90.     ])]
#   2%|▋                                       | 13/700 [11:35<9:56:35, 52.10s/it]
# Rp:8.231 | Rwp:11.352 | Rsquare:1.086
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 14-th iteration
# [array([ 8.48571,  5.40318,  6.96405, 90.     , 90.     , 90.     ])]
#   2%|▊                                       | 14/700 [12:22<9:39:55, 50.72s/it]
# Rp:8.034 | Rwp:11.103 | Rsquare:1.017
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 15-th iteration
# [array([ 8.48573,  5.4032 ,  6.96402, 90.     , 90.     , 90.     ])]
#   2%|▊                                       | 15/700 [13:13<9:39:04, 50.72s/it]
# Rp:7.860 | Rwp:10.887 | Rsquare:0.961
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 16-th iteration
# [array([ 8.48574,  5.40322,  6.96399, 90.     , 90.     , 90.     ])]
#   2%|▉                                       | 16/700 [14:03<9:35:24, 50.47s/it]
# Rp:7.706 | Rwp:10.699 | Rsquare:0.914
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 17-th iteration
# [array([ 8.48575,  5.40323,  6.96397, 90.     , 90.     , 90.     ])]
#   2%|▉                                       | 17/700 [14:51<9:27:08, 49.82s/it]
# Rp:7.568 | Rwp:10.534 | Rsquare:0.875
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 18-th iteration
# [array([ 8.48576,  5.40323,  6.96395, 90.     , 90.     , 90.     ])]
#   3%|█                                       | 18/700 [15:39<9:21:24, 49.39s/it]
# Rp:7.444 | Rwp:10.391 | Rsquare:0.844
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 19-th iteration
# [array([ 8.48578,  5.40324,  6.96393, 90.     , 90.     , 90.     ])]
#   3%|█                                       | 19/700 [16:27<9:14:59, 48.90s/it]
# Rp:7.333 | Rwp:10.264 | Rsquare:0.817
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 20-th iteration
# [array([ 8.48579,  5.40324,  6.96392, 90.     , 90.     , 90.     ])]
#   3%|█▏                                      | 20/700 [17:15<9:10:42, 48.59s/it]
# Rp:7.231 | Rwp:10.152 | Rsquare:0.794
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 21-th iteration
# [array([ 8.4858 ,  5.40324,  6.96391, 90.     , 90.     , 90.     ])]
#   3%|█▏                                      | 21/700 [18:03<9:08:56, 48.51s/it]
# Rp:7.137 | Rwp:10.053 | Rsquare:0.774
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 22-th iteration
# [array([ 8.48582,  5.40324,  6.9639 , 90.     , 90.     , 90.     ])]
#   3%|█▎                                      | 22/700 [18:52<9:06:48, 48.39s/it]
# Rp:7.050 | Rwp:9.965 | Rsquare:0.754
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 23-th iteration
# [array([ 8.48584,  5.40324,  6.96389, 90.     , 90.     , 90.     ])]
#   3%|█▎                                      | 23/700 [19:40<9:07:11, 48.50s/it]
# Rp:6.971 | Rwp:9.888 | Rsquare:0.738
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 24-th iteration
# [array([ 8.48585,  5.40324,  6.96388, 90.     , 90.     , 90.     ])]
#   3%|█▎                                      | 24/700 [20:28<9:04:19, 48.31s/it]
# Rp:6.900 | Rwp:9.821 | Rsquare:0.724
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 25-th iteration
# [array([ 8.48587,  5.40324,  6.96387, 90.     , 90.     , 90.     ])]
#   4%|█▍                                      | 25/700 [21:16<9:03:36, 48.32s/it]
# Rp:6.836 | Rwp:9.764 | Rsquare:0.712
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 26-th iteration
# [array([ 8.48588,  5.40324,  6.96386, 90.     , 90.     , 90.     ])]
#   4%|█▍                                      | 26/700 [22:06<9:05:12, 48.53s/it]
# Rp:6.779 | Rwp:9.713 | Rsquare:0.702
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 27-th iteration
# [array([ 8.4859 ,  5.40323,  6.96385, 90.     , 90.     , 90.     ])]
#   4%|█▌                                      | 27/700 [22:54<9:04:34, 48.55s/it]
# Rp:6.729 | Rwp:9.669 | Rsquare:0.693
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 28-th iteration
# [array([ 8.48591,  5.40323,  6.96384, 90.     , 90.     , 90.     ])]
#   4%|█▌                                      | 28/700 [23:42<9:02:19, 48.42s/it]
# Rp:6.683 | Rwp:9.630 | Rsquare:0.685
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 29-th iteration
# [array([ 8.48592,  5.40323,  6.96383, 90.     , 90.     , 90.     ])]
#   4%|█▋                                      | 29/700 [24:30<9:00:29, 48.33s/it]
# Rp:6.643 | Rwp:9.597 | Rsquare:0.679
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 30-th iteration
# [array([ 8.48594,  5.40322,  6.96382, 90.     , 90.     , 90.     ])]
#   4%|█▋                                      | 30/700 [25:18<8:58:54, 48.26s/it]
# Rp:6.606 | Rwp:9.567 | Rsquare:0.673
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 31-th iteration
# [array([ 8.48595,  5.40322,  6.96381, 90.     , 90.     , 90.     ])]
#   4%|█▊                                      | 31/700 [26:07<8:57:59, 48.25s/it]
# Rp:6.573 | Rwp:9.540 | Rsquare:0.668
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 32-th iteration
# [array([ 8.48596,  5.40322,  6.9638 , 90.     , 90.     , 90.     ])]
#   5%|█▊                                      | 32/700 [26:55<8:57:41, 48.30s/it]
# Rp:6.544 | Rwp:9.517 | Rsquare:0.663
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 33-th iteration
# [array([ 8.48597,  5.40321,  6.9638 , 90.     , 90.     , 90.     ])]
#   5%|█▉                                      | 33/700 [27:43<8:55:17, 48.15s/it]
# Rp:6.518 | Rwp:9.496 | Rsquare:0.660
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 34-th iteration
# [array([ 8.48599,  5.40321,  6.96379, 90.     , 90.     , 90.     ])]
#   5%|█▉                                      | 34/700 [28:31<8:54:53, 48.19s/it]
# Rp:6.495 | Rwp:9.477 | Rsquare:0.656
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 35-th iteration
# [array([ 8.486  ,  5.4032 ,  6.96378, 90.     , 90.     , 90.     ])]
#   5%|█▉                                      | 34/700 [29:20<9:34:46, 51.78s/it]
# Rp:6.474 | Rwp:9.460 | Rsquare:0.653
# After update the background :   Rp = 3.023 | Rwp = 7.124 | Rsquare = 0.535
# Mass fraction without structure factor estimate in % : [100.0]
#  Saved at the result documents
# 35-th iterations, reach the limit of ϵ.
#  Rp: 3.023
# Rwp: 7.124
#
#
# WPEM program running time :  0 hours 29 minute  38 second
# ('0 hours 29 minute  38 second  ',
#  [array([ 8.486  ,  5.4032 ,  6.96378, 90.     , 90.     , 90.     ])])
