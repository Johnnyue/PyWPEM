# %% [markdown]
# ## 1: background intensity

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-09-24 10:12:16  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
Var = WPEM.BackgroundFit(intensity_csv, LFctg=0.2, lowAngleRange=20, window_length = 7, bac_num=500)
Var
# Out:
# 6.251768943002127

# %% [markdown]
# ## 2: Wpen fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [[5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.  ,'fixed'],
                     [ 8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90. ,'fixed'  ]]

# Execute the model
WPEM.XRDfit(
    wavelength, Var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=11 ,low_bound=20,up_bound=41,bta = 0.9,iter_max = 100, asy_C = 0, 
    InitializationEpoch=2,loadParams=0,)
# Out:
# Started at Sun Sep 24 10:22:14 2023
#
# The lattice constants of input system 0 are fixed
# viz., fixed : [5.63625, 5.63625, 5.63625, 90.0, 90.0, 90.0]
# The lattice constants of input system 1 are fixed
# viz., fixed : [8.35992, 4.97708, 6.19713, 90.0, 114.69803, 90.0]
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Cubic  |  The initial lattice constants : 5.63625 5.63625 5.63625 90.0 90.0 90.0
# The input crystal system is: Monoclinic  |  The initial lattice constants : 8.35992 4.97708 6.19713 90.0 114.69803 90.0
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#
# WPEM 1-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:27.303 | Rwp:42.332 | Rsquare:7.636
# WPEM 2-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:18.358 | Rwp:28.736 | Rsquare:2.528
# WPEM 3-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:15.739 | Rwp:24.135 | Rsquare:1.572
# WPEM 4-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:14.550 | Rwp:21.929 | Rsquare:1.298
# WPEM 5-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:13.931 | Rwp:20.704 | Rsquare:1.215
# WPEM 6-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:13.471 | Rwp:19.912 | Rsquare:1.176
# WPEM 7-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:13.124 | Rwp:19.312 | Rsquare:1.144
# WPEM 8-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:12.804 | Rwp:18.779 | Rsquare:1.113
# WPEM 9-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:12.505 | Rwp:18.258 | Rsquare:1.083
# WPEM 10-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:12.233 | Rwp:17.781 | Rsquare:1.055
# WPEM 11-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:12.004 | Rwp:17.376 | Rsquare:1.027
# WPEM 12-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:11.807 | Rwp:17.026 | Rsquare:0.996
# WPEM 13-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:11.633 | Rwp:16.713 | Rsquare:0.964
# WPEM 14-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:11.475 | Rwp:16.428 | Rsquare:0.931
# WPEM 15-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:11.327 | Rwp:16.167 | Rsquare:0.900
# WPEM 16-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:11.192 | Rwp:15.929 | Rsquare:0.869
# WPEM 17-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:11.064 | Rwp:15.711 | Rsquare:0.840
# WPEM 18-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.944 | Rwp:15.510 | Rsquare:0.812
# WPEM 19-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.833 | Rwp:15.324 | Rsquare:0.785
# WPEM 20-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.730 | Rwp:15.151 | Rsquare:0.760
# WPEM 21-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.632 | Rwp:14.989 | Rsquare:0.736
# WPEM 22-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.538 | Rwp:14.836 | Rsquare:0.713
# WPEM 23-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.446 | Rwp:14.691 | Rsquare:0.692
# WPEM 24-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.358 | Rwp:14.554 | Rsquare:0.671
# WPEM 25-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.272 | Rwp:14.423 | Rsquare:0.651
# WPEM 26-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.188 | Rwp:14.299 | Rsquare:0.632
# WPEM 27-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.107 | Rwp:14.181 | Rsquare:0.614
# WPEM 28-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:10.033 | Rwp:14.068 | Rsquare:0.596
# WPEM 29-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.963 | Rwp:13.961 | Rsquare:0.580
# WPEM 30-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.896 | Rwp:13.860 | Rsquare:0.564
# WPEM 31-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.832 | Rwp:13.764 | Rsquare:0.549
# WPEM 32-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.771 | Rwp:13.673 | Rsquare:0.534
# WPEM 33-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.712 | Rwp:13.587 | Rsquare:0.520
# WPEM 34-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.654 | Rwp:13.507 | Rsquare:0.507
# WPEM 35-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.599 | Rwp:13.431 | Rsquare:0.495
# WPEM 36-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.546 | Rwp:13.361 | Rsquare:0.483
# WPEM 37-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.495 | Rwp:13.295 | Rsquare:0.472
# WPEM 38-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.445 | Rwp:13.233 | Rsquare:0.461
# WPEM 39-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.399 | Rwp:13.176 | Rsquare:0.451
# WPEM 40-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.354 | Rwp:13.123 | Rsquare:0.442
# WPEM 41-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.310 | Rwp:13.073 | Rsquare:0.433
# WPEM 42-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.268 | Rwp:13.027 | Rsquare:0.424
# WPEM 43-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.235 | Rwp:12.984 | Rsquare:0.416
# WPEM 44-th iteration
# [array([ 5.63625,  5.63625,  5.63625, 90.     , 90.     , 90.     ]), array([  8.35992,   4.97708,   6.19713,  90.     , 114.69803,  90.     ])]
# Rp:9.208 | Rwp:12.945 | Rsquare:0.409
# After update the background :   Rp = 6.420 | Rwp = 10.918 | Rsquare = 0.387
# volume fraction without structure factor estimate in % : [52.72704907833863, 47.27295092166137]
#  Saved at the result documents
# 44-th iterations, reach the limit of ϵ.
#  Rp: 6.420
# Rwp: 10.918
#
#
# WPEM program running time :  0 hours 10 minute  43 second
# '0 hours 10 minute  43 second  '

# %%
name = ['Li2CO3']
wavelength = [1.540593*2/3+ 1.544414*1/3]
WPEM.Plot_Components(lowboundary=20, upboundary=50,name = name, wavelength = wavelength, phase=1)
# Out:
# Name assigned successfully
