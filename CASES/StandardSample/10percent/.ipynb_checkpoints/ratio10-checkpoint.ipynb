# %% [markdown]
# ## 1: background intensity

# %%
from PyXplore import WPEM
import pandas as pd
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2026-02-06 14:17:55  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv, LFctg=0.2, lowAngleRange=20, window_length = 7, bac_num=500)
# Out:
# ================================

# %% [markdown]
# ## 2: Wpen fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [[ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.  ,'fixed'  ],
                     [  8.36041,   4.97669,   6.19737,  90   , 114.6978 ,  90 ,'fixed'  ]]

# Execute the model
WPEM.XRDfit(
    wavelength, var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=11 ,low_bound=20,up_bound=50,bta = 0.9,iter_max = 100, asy_C = 0, 
    InitializationEpoch=2,  num=1, Ave_Waves=True,)
# Out:
# Started at Fri Feb  6 14:22:01 2026
#
# The lattice constants of input system 0 are fixed
# viz., fixed : [5.62674, 5.62674, 5.62674, 90.0, 90.0, 90.0]
# The lattice constants of input system 1 are fixed
# viz., fixed : [8.36041, 4.97669, 6.19737, 90, 114.6978, 90]
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Cubic  |  The initial lattice constants : 5.62674 5.62674 5.62674 90.0 90.0 90.0
# The input crystal system is: Monoclinic  |  The initial lattice constants : 8.36041 4.97669 6.19737 90 114.6978 90
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                   | 0/100 [00:00<?, ?it/s]WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 1-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   1%|▍                                          | 1/100 [00:11<18:53, 11.45s/it]
# Rp:45.514 | Rwp:68.286 | Rsquare:18.583
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 2-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   2%|▊                                          | 2/100 [00:22<18:24, 11.27s/it]
# Rp:31.197 | Rwp:48.785 | Rsquare:7.700
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 3-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   3%|█▎                                         | 3/100 [00:33<17:54, 11.08s/it]
# Rp:28.867 | Rwp:44.540 | Rsquare:7.434
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 4-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   4%|█▋                                         | 4/100 [00:44<17:32, 10.96s/it]
# Rp:27.999 | Rwp:42.808 | Rsquare:7.443
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 5-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   5%|██▏                                        | 5/100 [00:55<17:16, 10.91s/it]
# Rp:27.421 | Rwp:41.869 | Rsquare:7.436
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 6-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   6%|██▌                                        | 6/100 [01:05<17:00, 10.85s/it]
# Rp:26.964 | Rwp:41.212 | Rsquare:7.403
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 7-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   7%|███                                        | 7/100 [01:16<16:51, 10.88s/it]
# Rp:26.574 | Rwp:40.695 | Rsquare:7.357
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 8-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   8%|███▍                                       | 8/100 [01:27<16:38, 10.85s/it]
# Rp:26.238 | Rwp:40.283 | Rsquare:7.304
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 9-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#   9%|███▊                                       | 9/100 [01:38<16:26, 10.84s/it]
# Rp:25.945 | Rwp:39.951 | Rsquare:7.246
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 10-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  10%|████▏                                     | 10/100 [01:49<16:11, 10.80s/it]
# Rp:25.719 | Rwp:39.672 | Rsquare:7.185
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 11-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  11%|████▌                                     | 11/100 [02:00<16:11, 10.92s/it]
# Rp:25.573 | Rwp:39.426 | Rsquare:7.124
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 12-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  12%|█████                                     | 12/100 [02:11<15:57, 10.88s/it]
# Rp:25.444 | Rwp:39.197 | Rsquare:7.062
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 13-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  13%|█████▍                                    | 13/100 [02:22<15:52, 10.95s/it]
# Rp:25.326 | Rwp:38.976 | Rsquare:7.000
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 14-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  14%|█████▉                                    | 14/100 [02:32<15:38, 10.91s/it]
# Rp:25.214 | Rwp:38.753 | Rsquare:6.935
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 15-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  15%|██████▎                                   | 15/100 [02:43<15:23, 10.86s/it]
# Rp:25.104 | Rwp:38.519 | Rsquare:6.864
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 16-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  16%|██████▋                                   | 16/100 [02:54<15:09, 10.83s/it]
# Rp:24.986 | Rwp:38.263 | Rsquare:6.783
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 17-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  17%|███████▏                                  | 17/100 [03:05<14:59, 10.83s/it]
# Rp:24.853 | Rwp:37.969 | Rsquare:6.685
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 18-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  18%|███████▌                                  | 18/100 [03:16<14:47, 10.82s/it]
# Rp:24.693 | Rwp:37.620 | Rsquare:6.563
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 19-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  19%|███████▉                                  | 19/100 [03:26<14:34, 10.80s/it]
# Rp:24.494 | Rwp:37.196 | Rsquare:6.414
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 20-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  20%|████████▍                                 | 20/100 [03:37<14:22, 10.78s/it]
# Rp:24.257 | Rwp:36.694 | Rsquare:6.245
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 21-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  21%|████████▊                                 | 21/100 [03:48<14:14, 10.82s/it]
# Rp:23.990 | Rwp:36.132 | Rsquare:6.070
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 22-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  22%|█████████▏                                | 22/100 [03:59<14:08, 10.88s/it]
# Rp:23.714 | Rwp:35.544 | Rsquare:5.906
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 23-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  23%|█████████▋                                | 23/100 [04:10<14:05, 10.99s/it]
# Rp:23.442 | Rwp:34.965 | Rsquare:5.762
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 24-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  24%|██████████                                | 24/100 [04:21<13:56, 11.01s/it]
# Rp:23.182 | Rwp:34.419 | Rsquare:5.635
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 25-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  25%|██████████▌                               | 25/100 [04:32<13:43, 10.99s/it]
# Rp:22.936 | Rwp:33.911 | Rsquare:5.524
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 26-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  26%|██████████▉                               | 26/100 [04:43<13:30, 10.95s/it]
# Rp:22.702 | Rwp:33.441 | Rsquare:5.421
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 27-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  27%|███████████▎                              | 27/100 [04:54<13:16, 10.91s/it]
# Rp:22.481 | Rwp:33.006 | Rsquare:5.326
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 28-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  28%|███████████▊                              | 28/100 [05:05<13:01, 10.85s/it]
# Rp:22.271 | Rwp:32.605 | Rsquare:5.235
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 29-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  29%|████████████▏                             | 29/100 [05:15<12:48, 10.82s/it]
# Rp:22.073 | Rwp:32.236 | Rsquare:5.149
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 30-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  30%|████████████▌                             | 30/100 [05:26<12:37, 10.82s/it]
# Rp:21.886 | Rwp:31.900 | Rsquare:5.068
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 31-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  31%|█████████████                             | 31/100 [05:37<12:28, 10.85s/it]
# Rp:21.711 | Rwp:31.597 | Rsquare:4.991
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 32-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  32%|█████████████▍                            | 32/100 [05:48<12:17, 10.85s/it]
# Rp:21.549 | Rwp:31.327 | Rsquare:4.920
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 33-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  33%|█████████████▊                            | 33/100 [05:59<12:06, 10.85s/it]
# Rp:21.397 | Rwp:31.089 | Rsquare:4.854
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 34-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  34%|██████████████▎                           | 34/100 [06:10<11:54, 10.83s/it]
# Rp:21.255 | Rwp:30.882 | Rsquare:4.793
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 35-th iteration
# [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]), array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])]
#  34%|██████████████▎                           | 34/100 [06:21<12:20, 11.22s/it]
# Rp:21.125 | Rwp:30.704 | Rsquare:4.738
# After update the background :   Rp = 18.847 | Rwp = 29.563 | Rsquare = 4.727
# Mass fraction without structure factor estimate in % : [91.82922211440618, 8.170777885593811]
#  Saved at the result documents
# 35-th iterations, reach the limit of ϵ.
#  Rp: 18.847
# Rwp: 29.563
#
#
# WPEM program running time :  0 hours 6 minute  27 second
# ('0 hours 6 minute  27 second  ',
#  [array([ 5.62674,  5.62674,  5.62674, 90.     , 90.     , 90.     ]),
#   array([  8.36041,   4.97669,   6.19737,  90.     , 114.6978 ,  90.     ])])
